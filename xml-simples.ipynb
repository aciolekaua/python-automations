# %%
import xmltodict
import os
import json
from datetime import datetime
from dateutil import parser

def calSimples(RBT12,anexo,aliquota):
    aliquota_array = {
                1: {
                    1: {"Aliquota": 4, "Desconto": 0},
                    2: {"Aliquota": 7.3, "Desconto": 5940},
                    3: {"Aliquota": 9.5, "Desconto": 13860},
                    4: {"Aliquota": 10.7, "Desconto": 22500},
                    5: {"Aliquota": 14.3, "Desconto": 87300},
                    6: {"Aliquota": 19, "Desconto": 378000}
                },
                2: {
                    1: {"Aliquota": 4.5, "Desconto": 0},
                    2: {"Aliquota": 7.8, "Desconto": 5940},
                    3: {"Aliquota": 10, "Desconto": 13860},
                    4: {"Aliquota": 11.2, "Desconto": 22500},
                    5: {"Aliquota": 14.7, "Desconto": 85500},
                    6: {"Aliquota": 30, "Desconto": 720000}
                },
                3: {
                    1: {"Aliquota": 6, "Desconto": 0},
                    2: {"Aliquota": 11.2, "Desconto": 9360},
                    3: {"Aliquota": 13.5, "Desconto": 17640},
                    4: {"Aliquota": 16, "Desconto": 35640},
                    5: {"Aliquota": 21, "Desconto": 125640},
                    6: {"Aliquota": 33, "Desconto": 648000}
                },
                4: {
                    1: {"Aliquota": 4.5, "Desconto": 0},
                    2: {"Aliquota": 9, "Desconto": 8100},
                    3: {"Aliquota": 10.2, "Desconto": 12420},
                    4: {"Aliquota": 14, "Desconto": 39780},
                    5: {"Aliquota": 22, "Desconto": 183780},
                    6: {"Aliquota": 33, "Desconto": 828000}
                },
                5: {
                    1: {"Aliquota": 15.5, "Desconto": 0},
                    2: {"Aliquota": 18, "Desconto": 4500},
                    3: {"Aliquota": 19.5, "Desconto": 9900},
                    4: {"Aliquota": 20.5, "Desconto": 17100},
                    5: {"Aliquota": 23, "Desconto": 62100},
                    6: {"Aliquota": 30.5, "Desconto": 540000}
                }
            }
    imposto_array = {
            1: {
                1: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1274, "PIS": 0.0276, "CPP": 0.415, "ICMS": 0.34, "IPI": 0.0, "ISS": 0.0},
                2: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1151, "PIS": 0.0249, "CPP": 0.375, "IPI": 0.075, "ICMS": 0.32, "ISS": 0.0},
                3: {"IRPJ": 0.04, "CSLL": 0.035, "COFINS": 0.1282, "PIS": 0.0278, "CPP": 0.434, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.335},
                4: {"IRPJ": 0.188, "CSLL": 0.152, "COFINS": 0.1767, "PIS": 0.0383, "CPP": 0.0, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.445},
                5: {"IRPJ": 0.25, "CSLL": 0.15, "COFINS": 0.141, "PIS": 0.0305, "CPP": 0.2885, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.14}
            },
            2: {
                1: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1274, "PIS": 0.0276, "CPP": 0.415, "ICMS": 0.34, "IPI": 0.0, "ISS": 0.0},
                2: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1151, "PIS": 0.0249, "CPP": 0.375, "IPI": 0.075, "ICMS": 0.32, "ISS": 0.0},
                3: {"IRPJ": 0.04, "CSLL": 0.035, "COFINS": 0.1405, "PIS": 0.0305, "CPP": 0.434, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.32},
                4: {"IRPJ": 0.198, "CSLL": 0.152, "COFINS": 0.2055, "PIS": 0.0445, "CPP": 0.0, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.4},
                5: {"IRPJ": 0.23, "CSLL": 0.15, "COFINS": 0.141, "PIS": 0.0305, "CPP": 0.2785, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.17}
            },
            3: {
                1: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1274, "PIS": 0.0276, "CPP": 0.42, "ICMS": 0.335, "IPI": 0.0, "ISS": 0.0},
                2: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1151, "PIS": 0.0249, "CPP": 0.375, "IPI": 0.075, "ICMS": 0.32, "ISS": 0.0},
                3: {"IRPJ": 0.04, "CSLL": 0.035, "COFINS": 0.1364, "PIS": 0.0296, "CPP": 0.434, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.325},
                4: {"IRPJ": 0.208, "CSLL": 0.152, "COFINS": 0.1973, "PIS": 0.0427, "CPP": 0.0, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.4},
                5: {"IRPJ": 0.24, "CSLL": 0.15, "COFINS": 0.1492, "PIS": 0.0323, "CPP": 0.2385, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.19}
            },
            4: {
                1: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1274, "PIS": 0.0276, "CPP": 0.42, "ICMS": 0.335, "IPI": 0.0, "ISS": 0.0},
                2: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1151, "PIS": 0.0249, "CPP": 0.375, "IPI": 0.075, "ICMS": 0.32, "ISS": 0.0},
                3: {"IRPJ": 0.04, "CSLL": 0.035, "COFINS": 0.1364, "PIS": 0.0296, "CPP": 0.434, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.325},
                4: {"IRPJ": 0.178, "CSLL": 0.192, "COFINS": 0.189, "PIS": 0.041, "CPP": 0.0, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.4},
                5: {"IRPJ": 0.21, "CSLL": 0.15, "COFINS": 0.1574, "PIS": 0.0341, "CPP": 0.2385, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.21}
            },
            5: {
                1: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1274, "PIS": 0.0276, "CPP": 0.42, "ICMS": 0.335, "IPI": 0.0, "ISS": 0.0},
                2: {"IRPJ": 0.055, "CSLL": 0.035, "COFINS": 0.1151, "PIS": 0.0249, "CPP": 0.375, "IPI": 0.075, "ICMS": 0.32, "ISS": 0.0},
                3: {"IRPJ": 0.23, "CSLL": 0.15, "COFINS": 0.141, "PIS": 0.0305, "CPP": 0.2785, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.17},
                4: {"IRPJ": 0.188, "CSLL": 0.192, "COFINS": 0.1808, "PIS": 0.0392, "CPP": 0.0, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.4},
                5: {"IRPJ": 0.23, "CSLL": 0.125, "COFINS": 0.141, "PIS": 0.0305000000000001, "CPP": 0.2385, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.235}
            },
            6: {
                1: {"IRPJ": 0.135, "CSLL": 0.1, "COFINS": 0.2827, "PIS": 0.0613, "CPP": 0.421, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.0},
                2: {"IRPJ": 0.085, "CSLL": 0.075, "COFINS": 0.2096, "PIS": 0.0454, "CPP": 0.235, "IPI": 0.35, "ICMS": 0.0, "ISS": 0.0},
                3: {"IRPJ": 0.35, "CSLL": 0.15, "COFINS": 0.1603, "PIS": 0.0347, "CPP": 0.305, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.0},
                4: {"IRPJ": 0.535, "CSLL": 0.215, "COFINS": 0.2055, "PIS": 0.0445, "CPP": 0.0, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.0},
                5: {"IRPJ": 0.35, "CSLL": 0.155, "COFINS": 0.1644, "PIS": 0.0356, "CPP": 0.295, "ICMS": 0.0, "IPI": 0.0, "ISS": 0.0}
            }
        }

    
    if float(aliquota) > 1:
                float(aliquota) / 100
                #print("Está é a aliquota ",aliquota
                faixa = 0
                if RBT12 <= 180000:
                    faixa = 1
                elif 180000 < RBT12 <= 360000:
                    faixa = 2
                elif 360000 < RBT12 <= 720000:
                    faixa = 3
                elif 720000 < RBT12 <= 1800000:
                    faixa = 4
                elif 1800000 < RBT12 <= 3600000:
                    faixa = 5
                elif 3600000 < RBT12 <= 4800000:
                    faixa = 6


                aliquota = aliquota_array[anexo][faixa]['Aliquota']
                desconto = aliquota_array[anexo][faixa]['Desconto']
                
                aliquota = aliquota / 100
                
                aliquotaEfetiva = ((RBT12 * aliquota) - desconto) / RBT12
                
                aliquotaEfetiva = aliquotaEfetiva * 100
                
                irpj = imposto_array[anexo][faixa]["IRPJ"]
                csll = imposto_array[anexo][faixa]["CSLL"]
                cofins = imposto_array[anexo][faixa]["COFINS"]
                pis = imposto_array[anexo][faixa]["PIS"]
                cpp = imposto_array[anexo][faixa]["CPP"]
                icms = imposto_array[anexo][faixa]["ICMS"]
                ipi = imposto_array[anexo][faixa]["IPI"]
                iss = imposto_array[anexo][faixa]["ISS"]
                
                return [aliquotaEfetiva,irpj,csll,cofins,pis,cpp,icms,ipi,iss]

    

def pegar_infos(nome_arquivo, notas_dict):
    caminho_arquivo = os.path.join("nfse", nome_arquivo)
    
    with open(caminho_arquivo, "r", encoding="utf-8") as arquivo_xml:
        conteudo_xml = arquivo_xml.read()
        dic_arquivo = xmltodict.parse(conteudo_xml)
        
        try:
            infos_nfse = dic_arquivo["ConsultarNfsePorRpsResult"]["CompNfse"]["Nfse"]["InfNfse"]
            
            
            # Informações da nota fiscal
            id_nota = infos_nfse["@id"]

            # Converter Data de Emissao para d/m/Y H:i
            data_emissao = datetime.strptime(infos_nfse["DataEmissao"], "%Y-%m-%dT%H:%M:%SZ")
            data_emissao_formatted = data_emissao.strftime("%d/%m/%Y %H:%M")  

            # Converter Competencia para m/Y
            data_competencia = datetime.strptime(infos_nfse["Competencia"], "%Y%mZ")
            data_competencia_formatted = data_competencia.strftime("%m/%Y") 
            
            
            #data_emissao = infos_nfse["DataEmissao"]
            #data_competencia = infos_nfse["Competencia"]


            # Informações do serviço
            valores_servicos = infos_nfse["Servico"]["Valores"]["ValorServicos"]
            iss_retido = infos_nfse["Servico"]["Valores"]["IssRetido"]
            valor_iss = infos_nfse["Servico"]["Valores"]["ValorIss"]
            aliquota = infos_nfse["Servico"]["Valores"]["Aliquota"]

            # Informações do serviço específicas
            item_lista_servico = infos_nfse["Servico"]["ItemListaServico"]
            codigo_cnae = infos_nfse["Servico"]["CodigoCnae"]
            discriminacao = infos_nfse["Servico"]["Discriminacao"]
            codigo_municipio = infos_nfse["Servico"]["CodigoMunicipio"]

            # Informações do prestador de serviço
            cnpj_prestador = infos_nfse["PrestadorServico"]["IdentificacaoPrestador"]["Cnpj"]
            inscricao_municipal = infos_nfse["PrestadorServico"]["IdentificacaoPrestador"]["InscricaoMunicipal"]
            nome_fantasia = infos_nfse["PrestadorServico"]["NomeFantasia"]

            # Informações do tomador de serviço
            cnpj_tomador = infos_nfse["TomadorServico"]["IdentificacaoTomador"]["CpfCnpj"]["Cnpj"]
            razao_social_tomador = infos_nfse["TomadorServico"]["RazaoSocial"]
            
            notas_dict[id_nota] = {
                "ID Nota": id_nota,
                "Data de Emissao": data_emissao_formatted,
                "Competencia": data_competencia_formatted,
                "Valor dos Servicos": valores_servicos,
                "Iss Retido": iss_retido,
                "Valor Iss": valor_iss,
                "Aliquota": aliquota,
                "Item Lista Servico" : item_lista_servico,
                "Codigo Cnae": codigo_cnae,
                "Codigo Municipio": codigo_municipio,
                "CNPJ prestador" : cnpj_prestador,
                "Inscricao Municipal": inscricao_municipal,
                "Nome Fantasia": nome_fantasia,
                "CNPJ Tomador/CPF Tomador": cnpj_tomador,
                "Razao Social Tomador": razao_social_tomador,
                "Aliquota Efetiva": 0,
                "IRPJ":0,
                "CSLL":0,
                "COFINS":0,
                "PIS":0,
                "CPP":0,
                "ICMS":0,
                "IPI":0,
                "ISS":0
            }
            
        
        except KeyError as e:
            print(f"Erro ao processar o arquivo {nome_arquivo}: {e}")
            return

            
    
# Nome do arquivo de saída TXT
#arquivo_saida_txt = "impostos.txt"

# Dicionário para armazenar as informações das notas
notas_dict = {}

# Lista para armazenar os IDs das notas
lista_ids = notas_dict.keys()

# Lista os arquivos na pasta "nfse" e processa cada um
lista_arquivos = os.listdir("nfse")
for arquivo in lista_arquivos:
    pegar_infos(arquivo,notas_dict)

for id_notas in lista_ids:
    aliquota = notas_dict[id_notas]["Aliquota"]
    aliquotaEfetiva = calSimples(360000,3,aliquota)
#     print(aliquotaEfetiva)
#     notas_dict[id_notas]["Aliquota Efetiva"] = "{:.2f}".format(aliquotaEfetiva[0])
#     notas_dict[id_notas]["IRPJ"] = "{:.2f}".format(aliquotaEfetiva[1])
#     notas_dict[id_notas]["CSLL"] = "{:.2f}".format(aliquotaEfetiva[2])
#     notas_dict[id_notas]["COFINS"] = "{:.2f}".format(aliquotaEfetiva[3])
#     notas_dict[id_notas]["PIS"] = "{:.2f}".format(aliquotaEfetiva[4])
#     notas_dict[id_notas]["CPP"] = "{:.2f}".format(aliquotaEfetiva[5])
#     notas_dict[id_notas]["ICMS"] = "{:.2f}".format(aliquotaEfetiva[6])
#     notas_dict[id_notas]["IPI"] = "{:.2f}".format(aliquotaEfetiva[7])
#     notas_dict[id_notas]["ISS"] = "{:.2f}".format(aliquotaEfetiva[8])
    
    notas_dict[id_notas]["Aliquota Efetiva"] = aliquotaEfetiva[0]
    notas_dict[id_notas]["IRPJ"] = aliquotaEfetiva[1]
    notas_dict[id_notas]["CSLL"] = aliquotaEfetiva[2]
    notas_dict[id_notas]["COFINS"] = aliquotaEfetiva[3]
    notas_dict[id_notas]["PIS"] = aliquotaEfetiva[4]
    notas_dict[id_notas]["CPP"] = aliquotaEfetiva[5]
    notas_dict[id_notas]["ICMS"] = aliquotaEfetiva[6]
    notas_dict[id_notas]["IPI"] = aliquotaEfetiva[7]
    notas_dict[id_notas]["ISS"] = aliquotaEfetiva[8]


print(json.dumps(notas_dict, indent=4))
# with open("impostos.txt","a", encoding="utf-8") as imposto:
#     imposto.write(f"Impostos:{notas_dict[id_nota]}")
# Out:
# {
#     "NFSE-OLINDA-0926051-231122-153516-000000768-362571871": {
#         "ID Nota": "NFSE-OLINDA-0926051-231122-153516-000000768-362571871",
#         "Data de Emissao": "2023-11-22T15:35:01Z",
#         "Valor dos Servicos": "400.00",
#         "Iss Retido": "2",
#         "Valor Iss": "20.00",
#         "Aliquota": "5.00",
#         "Item Lista Servico": "17.18",
#         "Codigo Cnae": "6920601",
#         "Codigo Municipio": "2609600",
#         "CNPJ prestador": "11316866000122",
#         "Inscricao Municipal": "0926051",
#         "Nome Fantasia": "PERNAMBUCONT",
#         "CNPJ Tomador/CPF Tomador": "22148707000182",
#         "Razao Social Tomador": "SPEEDMAIS SOLUCOES LTDA",
#         "Aliquota Efetiva": 8.599999999999998,
#         "IRPJ": 0.055,
#         "CSLL": 0.035,
#         "COFINS": 0.1151,
#         "PIS": 0.0249,
#         "CPP": 0.375,
#         "ICMS": 0.32,
#         "IPI": 0.075,
#         "ISS": 0.0
#     },
# ...
